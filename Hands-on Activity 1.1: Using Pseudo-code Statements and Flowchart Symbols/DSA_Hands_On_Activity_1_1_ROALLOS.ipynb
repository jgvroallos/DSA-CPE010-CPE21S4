# %% [markdown]
# <a href="https://colab.research.google.com/github/jgvroallos/DSA-CPE010-CPE21S4/blob/main/Hands-on%20Activity%201.1%3A%20Using%20Pseudo-code%20Statements%20and%20Flowchart%20Symbols/DSA_Hands_On_Activity_1_1_ROALLOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem No.1

# %% [markdown]
# ![Problem1_ROALLOS.png](data:image/png;base64,...)

# %% [markdown]
# *Made in Lucidchart*

# %% [markdown]
# # Problem No.2

# %% [markdown]
# ![Problem2_ROALLOS.png](data:image/png;base64,...)

# %% [markdown]
# *Made in Lucidchart*
